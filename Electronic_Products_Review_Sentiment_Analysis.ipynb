# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import twitter_samples 
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import string
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import seaborn as sns
import time
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## **Importing and Reviewing Data**

# %%
dataset = pd.read_json('/content/drive/My Drive/Machine Learning/Sentiment_Analysis/Electronics_5.json', lines = True)

# %% [markdown]
# Let's first check the data content.

# %%
dataset.head()
# Out:
#        reviewerID        asin  ... unixReviewTime   reviewTime
# 0   AO94DHGC771SJ  0528881469  ...     1370131200   06 2, 2013
# 1   AMO214LNFCEI4  0528881469  ...     1290643200  11 25, 2010
# 2  A3N7T0DY83Y4IG  0528881469  ...     1283990400   09 9, 2010
# 3  A1H8PY3QHMQQA0  0528881469  ...     1290556800  11 24, 2010
# 4  A24EV6RXELQZ63  0528881469  ...     1317254400  09 29, 2011
#
# [5 rows x 9 columns]

# %% [markdown]
# Checking for null values:

# %%
dataset.isnull().sum()
# Out:
# reviewerID            0
# asin                  0
# reviewerName      24730
# helpful               0
# reviewText            0
# overall               0
# summary               0
# unixReviewTime        0
# reviewTime            0
# dtype: int64

# %% [markdown]
# In this datset, we will use the 'reviewText' and 'overal' columns, which are the reviews and the corresponding rating provided by the reviewer.
# The overal review rating is an integer from 1 to 5. In this project, we want to train a logistic regression model that can predict the review as being positive or negative. Hence, we consider reviews with rate of 4 and 5 as positive, and rates of 1 and 2 as negative reviews. We will ignore the rates of 3 (the neutral ratings).
#
# Let's check the frequency of each review rating:

# %%
dataset['overall'].value_counts()
# Out:
# 5    1009026
# 4     347041
# 3     142257
# 1     108725
# 2      82139
# Name: overall, dtype: int64

# %% [markdown]
# Using the criteria mentioned above, let's categorize the reviews as positive and negative:

# %%
positive_boolean = dataset['overall'] >= 4
negative_boolean = dataset['overall'] <= 2

# %%
positive_reviews = dataset['reviewText'].loc[positive_boolean]
pos_reviews = positive_reviews.to_list()

# %%
negative_reviews = dataset['reviewText'].loc[negative_boolean]
neg_reviews = negative_reviews.to_list()

# %%
n_pos = len(positive_reviews)
n_neg = len(negative_reviews)
print(f'We have {n_pos} positive reviews and {n_neg} negative reviews')
# Out:
# We have 1356067 positive reviews and 190864 negative reviews

# %% [markdown]
# Let's take a look at some example random reviews:

# %%
print('Example of a positive review:\n', pos_reviews[1010], '\n')
print(pos_reviews[100000], '\n')
print('\nExample of a negative review:\n', neg_reviews[2104], '\n')
print(neg_reviews[12000])
# Out:
# Example of a positive review:
#  I wanted a radio to listen to NPR for a few minutes in the morning without putting on the stereo.  I did not want a CD or tape player.  This is a good little basic radio and I am pleased with it.
#
# This switch works as described, nothing more nothing less.  The 4sSignal passing through it is clean and no difference is observed when it is installed.  It operates exactly as expected.
#
#
# Example of a negative review:
#  Cons: this camera is heavy and bulky.  For the price, it is only around 2 mega pixels which isnt good.  I had this camera for a while then the zoom wouldnt come all the way out and it says "system error" every time  i turn it on so i cannot use it anymore.Pros:  the pictures turn out decent.  It is a solid camera but do not drop it on the lens contraption because you will have the same problem of it not turning on and its garabe now.
#
# I tried to attach this cable to link my HDTV and computer but apparently I am missing something...I still have to do more research perhaps////

# %% [markdown]
# We will use 100,000 positive and 100,000 negative reviews. Based on the performance analysis, we will decide if more data is required or not.

# %%
pos_reviews = pos_reviews[:100000]
neg_reviews = neg_reviews[:100000]

# %% [markdown]
# Define training and test data with 80/20 ratio.

# %%
X_train_pos = pos_reviews[:80000]  # 80% of data
X_train_neg = neg_reviews[:80000]
X_test_pos = pos_reviews[80000:]
X_test_neg = neg_reviews[80000:]
X_train = X_train_pos + X_train_neg
X_test = X_test_pos + X_test_neg
y_train = np.append(np.ones((80000,1)), np.zeros((80000,1)), axis = 0) 
y_test = np.append(np.ones((20000, 1)), np.zeros((20000,1)), axis = 0)

# %% [markdown]
# Define a function to preprocess the review texts. This included removing punctuations, digits, stop words,... and tokenization.
# We are also using word stemmer.

# %%
def preprocess_text(review):
  stopwords_english = stopwords.words('english')
  review = re.sub(r'\d','', review)
  review = re.sub(r'"','', review)
  review = re.sub(r'\.\.\.','', review)
  review = re.sub(r'[A-Z]{2,}', '', review)
  review = re.sub(r"n't", "not", review)
  review = re.sub(r"\'s", "", review)
  review = re.sub(r"\'ve", "have", review)
  review = re.sub(r"\'re", "are", review)
  review = re.sub(r"\'d", "would", review)
  review = re.sub(r"\'ll", "will", review)
  review = re.sub(r"i'm", "I am", review)
  stemmer = PorterStemmer()
  review_lower = review.lower()
  review_tokens = word_tokenize(review_lower)
  processed_text =[]
  for word in review_tokens:
    if (word not in stopwords.words('english') and word not in string.punctuation):
      stem_word = stemmer.stem(word)
      processed_text.append(stem_word)
  return processed_text

# %% [markdown]
# Define a function to provide us with the frequency of each word in the positive and negative categories in a frequency dictionary.

# %%
def freq_dict(reviews, y):
  y_list = np.squeeze(y).tolist()
  freq = {}
  for review,y in zip(reviews, y_list):
    review_p = preprocess_text(review)
    for word in review_p:
      key = (word, y)
      if key in freq:
        freq[key] += 1
      else:
        freq[key] = 1
  return freq

# %% [markdown]
# Use the above function to create our frequency dictionary.

# %%
t_start = time.time()
freqs = freq_dict(X_train,y_train)
print('execution time is:  ', round((time.time() - t_start)/60, 2), 'mins')
# Out:
# execution time is:   57.77 mins

# %% [markdown]
# Now, we need to create feature vectors for logistic regression. We will use a (1,3) vector for each word. The first element of this vector is equal to 1 for all words. The second and third elements correspond to the summation of the frequencies of word in positive and negative categories, respectively.

# %%
def features(review,freqs):
  review_p = preprocess_text(review)
  x = np.zeros((1,3))
  x[0,0] = 1
  for word in review_p:
    x[0,1] += freqs.get((word, 1), 0)
    x[0,2] += freqs.get((word,0), 0)
  return x

# %%
t_start = time.time()
X = np.zeros((len(X_train), 3))
for i in range(len(X_train)):
  X[i, :] = features(X_train[i], freqs) 
print('execution time is:  ', round((time.time() - t_start)/60, 2), 'mins')
# Out:
# execution time is:   57.73 mins

# %%
Xtest = np.zeros((len(X_test), 3))
for i in range(len(X_test)):
  Xtest[i, :] = features(X_test[i], freqs)

# %% [markdown]
# Train the logistic regression model using the training data features, and predict the review sentiments for test data:

# %%
lr = LogisticRegression(solver = 'liblinear', random_state = 42, max_iter=1000)
lr.fit(X,y_train.ravel())
y_pred_train = lr.predict(X)
y_pred_test = lr.predict(Xtest)

# %% [markdown]
# ## **Model Performance Analysis**

# %% [markdown]
# Calculate the accuracy and F1-score for training and test data:

# %%
print('For training data:')
print("Accuracy: ",round(metrics.accuracy_score(y_train,y_pred_train),3))
print("F1-score: ",round(metrics.f1_score(y_train, y_pred_train),3))
# Out:
# For training data:
# Accuracy:  0.745
# F1-score:  0.738

# %%
print('For test data: ')
print("Accuracy: ",round(metrics.accuracy_score(y_test,y_pred_test),3))
print("F1-score: ",round(metrics.f1_score(y_test, y_pred_test),3))
# Out:
# For test data:
# Accuracy:  0.709
# F1-score:  0.689

# %% [markdown]
# The accuracy seems acceptable for a logistic regression for sentiment analysis. Also, the test accuracy is quite close to the training accuracy. Hence, we don't have a big variance, which means adding more data will not improve the model performance.
#
# Create the confusion matrix for visual analysis of the performance:

# %%
cm = metrics.confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r')
plt.xlabel('Predicted Sentiment')
plt.ylabel('Actual Sentiment')
# Out:
# Text(15.0, 0.5, 'Actual Sentiment')

# %% [markdown]
# Let's see which words are the most frequent ones in this data.

# %%
sorted_freq = {k:v for k,v in sorted(freqs.items(), key = lambda item:item[1], reverse = True)}

# %%
def top_words_plt(sorted_freq): # n refering to 0 or 1 for negative or positive
  category = ['negative', 'positive']
  c = ['red', 'green']
  fig, ax = plt.subplots(1,2, figsize = (20,5))
  for n in range(0,2):
    most_common = {}
    i = 1
    for key, freq in sorted_freq.items():
      if key[1] == n:
        most_common[key[0]] = freq
        i += 1
        if i > 30:
          break
    ax[n].bar(most_common.keys(), most_common.values(), color = c[n])
    ax[n].set_title('Most common words for '+ category[n]+ ' category')
    ax[n].set_xlabel('words')
    ax[n].set_ylabel('frequency')
    xlabels = most_common.keys()
    ax[n].set_xticklabels(xlabels, rotation = 60)

# %%
top_words_plt(sorted_freq)

# %%
pos_reviews_train = "".join(review for review in X_train_pos)
neg_reviews_train = "".join(review for review in X_train_neg)

wordcloud_pos = WordCloud(background_color='white').generate(pos_reviews_train)
wordcloud_neg = WordCloud(background_color='white').generate(neg_reviews_train)

# %%
fig, ax = plt.subplots(1,2, figsize = (15,8))
ax[0].imshow(wordcloud_pos, interpolation = 'bilinear')
ax[0].set_title('Word Cloud for Positive Reviews')
ax[1].imshow(wordcloud_neg, interpolation = 'bilinear')
ax[1].set_title('Word Cloud for Negative Reviews')
ax[0].axis('off')
ax[1].axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# The logistic regression model seems to provide an okay prediction performance with accuracy and F1-score of around 0.70. As shown with the bar chart of frequencies as well as in the word cloud plots, we wee a high frequency use of neutral words such as 'one', 'use', 'thing', ...in both positive and negative sentiment categories. There is very small difference in the frequency of these neutral words, which may be contributing to part of the error. At the same time, we see that the positive and negative sentiment reviews are indeed correlated with the use of positive and negative sentiment words such as "great" and "good".
# To get a better prediction performance, the model needs to capture the context of words in each review. This cannot be done with logistic regression approach.
